# %% [markdown]
# # Análise de Dados
#
# - [Análise de Dados](https://medium.com/@aasouzaconsult/an%C3%A1lise-de-dados-91a93b0c1312)

# %% [markdown]
# # Acessando o PostgreSQL via Python
# - Consultando tabelas e views
# - Análise Exploratória de Dados

# %% [markdown]
# ## Conectando ao PostgreSQL

# %% [markdown]
# Pode ser que peça para instalar o Pyodbc, Seaborn e matplotlib (pip instal...)
#
# Baixe o ODBC do PostgreSQL e instale
# https://www.postgresql.org/ftp/odbc/versions/msi/

# %%
# Usaremos o PostgreSQL Unicode, se fosse SQL Server, usariamos o ODBC Driver 17 for SQL Server
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'MySQL ODBC 8.0 ANSI Driver',
#  'MySQL ODBC 8.0 Unicode Driver',
#  'SQL Server Native Client 11.0',
#  'ODBC Driver 17 for SQL Server',
#  'SQL Server Native Client RDA 11.0',
#  'ODBC Driver 13 for SQL Server',
#  'Simba Spark ODBC Driver',
#  'Simba Athena ODBC Driver',
#  'SQLite3 ODBC Driver',
#  'SQLite ODBC Driver',
#  'SQLite ODBC (UTF-8) Driver',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)',
#  'PostgreSQL ANSI(x64)',
#  'PostgreSQL Unicode(x64)',
#  'PostgreSQL ANSI',
#  'PostgreSQL Unicode']

# %%
# Suppress all warnings
import warnings
warnings.filterwarnings("ignore")

# Importing the libraries
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
conn = pyodbc.connect(DRIVER = '{PostgreSQL Unicode}',
                      SERVER = 'localhost',
                      DATABASE = 'postgres',
                      UID = 'postgres',
                      PWD = 'sua senha aqui')

cursor = conn.cursor()

# %% [markdown]
# ## Consultando tabelas

# %%
SQL_Query = pd.read_sql_query('select * FROM fato_vendas', conn)
fato_vendas = pd.DataFrame(SQL_Query)

# %%
fato_vendas
# Out:
#      codigovenda   datavenda  codigocliente  codigoproduto  quantidade  \
# 0              1  2010-02-01              1           1.00        4000
# 1              2  2010-02-01              1            NaN        4000
# 2              3  2010-02-01              5           1.00        4200
# 3              4  2010-02-02              3           2.00         250
# 4              5  2010-02-03              4           1.00        4500
# ..           ...         ...            ...            ...         ...
# 214          247  2020-04-01             18           5.00       20030
# 215          248  2023-02-01             18           5.00       20030
# 216          249  2023-03-01             18           5.00       20030
# 217          250  2023-04-01             18           5.00       30030
# 218          251  2023-04-07             18           5.00       10030
#
#      valorunitario  codigovendedor  codigocanalvendas  codigostatus  deletado
# 0             0.34               2                  1             1         0
# 1             0.34               2                  1             1         0
# 2             0.34               4                  1             1         0
# 3             7.00               2                  1             1         0
# 4             0.34               1                  1             1         0
# ..             ...             ...                ...           ...       ...
# 214           9.00               2                  1             1         0
# 215           9.00               2                  1             1         0
# 216           9.00               2                  1             1         0
# 217           9.00               2                  1             1         0
# 218           9.00               2                  1             1         0
#
# [219 rows x 10 columns]

# %%
SQL_Query = pd.read_sql_query('select * FROM dim_produto', conn)
dim_produto = pd.DataFrame(SQL_Query)

# %%
dim_produto
# Out:
#    codigoproduto nomeproduto tipoproduto unidadeproduto  saldoproduto  \
# 0              1   Produto A           A             KG         20000
# 1              2   Produto C           A             KG          5000
# 2              3   Produto E           B             KG          2000
# 3              5  Produto CH           A             KG          2000
# 4              4  Produto SL           A             KG         30000
# 5              6  Produto TN           C             KG          1000
# 6              8  Produto AA           A             KG         20000
# 7              9        None           A             KG         20000
#
#      statusproduto
# 0            Ativo
# 1            Ativo
# 2            Ativo
# 3            Ativo
# 4            Ativo
# 5  MVP - validação
# 6            Ativo
# 7          Inativo

# %%
SQL_Query = pd.read_sql_query('select * FROM dim_cliente', conn)
dim_cliente = pd.DataFrame(SQL_Query)

# %%
dim_cliente
# Out:
#     codigocliente  nomecliente  idade  classificacao sexo          cidade  \
# 0               1   Cliente AA     30              3    M   Florianópolis
# 1               5   Cliente BB     20              2    F  Belo Horizonte
# 2               3   Cliente BC     25              4    M        Baturité
# 3               4   Cliente CC     19              2    F       Fortaleza
# 4               6   Cliente DD     19              2    F         Goiânia
# 5               7   Cliente DE     39              5    F     João Pessoa
# 6               8   Cliente EE     26              4    M           Natal
# 7               2   Cliente EF     31              3    M  Belo Horizonte
# 8              10  Cliente ABC     50              1    M       São Paulo
# 9               9  Cliente BCA     25              4    F  Rio de Janeiro
# 10             11  Cliente CCC     18              2    F        Salvador
# 11             13  Cliente MAC     37              5    F          Maceió
# 12             14  Cliente MGS     50              1    F    Campo Grande
# 13             18  Cliente GRM     55              1    M         Gramado
# 14             16  Cliente PIR     32              3    M        Piripiri
# 15             17  Cliente MTG     38              5    F          Palmas
#
#                  estado    pais
# 0        Santa Catarina  Brasil
# 1          Minas Gerais  Brasil
# 2                 Ceará  Brasil
# 3                 Ceará  Brasil
# 4                 Goiás  Brasil
# 5               Paraíba  Brasil
# 6   Rio Grande do Norte  Brasil
# 7          Minas Gerais  Brasil
# 8             São Paulo  Brasil
# 9        Rio de Janeiro  Brasil
# 10                Bahia  Brasil
# 11              Alagoas  Brasil
# 12   Mato Grosso do Sul  Brasil
# 13    Rio Grande do Sul  Brasil
# 14                Piauí  Brasil
# 15            Tocantins  Brasil

# %%
# Usando RIGHT Join
sql = """
      SELECT ven.*,
             pro.NomeProduto,
             pro.UnidadeProduto
        FROM      fato_vendas ven 
        RIGHT JOIN dim_produto pro ON pro.CodigoProduto = ven.CodigoProduto;
      """
pd.read_sql(sql, conn)
# Out:
#      codigovenda   datavenda  codigocliente  codigoproduto  quantidade  \
# 0           1.00  2010-02-01           1.00           1.00     4000.00
# 1           3.00  2010-02-01           5.00           1.00     4200.00
# 2           4.00  2010-02-02           3.00           2.00      250.00
# 3           5.00  2010-02-03           4.00           1.00     4500.00
# 4           7.00  2010-03-05           6.00           1.00    12500.00
# ..           ...         ...            ...            ...         ...
# 215       249.00  2023-03-01          18.00           5.00    20030.00
# 216       250.00  2023-04-01          18.00           5.00    30030.00
# 217       251.00  2023-04-07          18.00           5.00    10030.00
# 218          NaN        None            NaN            NaN         NaN
# 219          NaN        None            NaN            NaN         NaN
#
#      valorunitario  codigovendedor  codigocanalvendas  codigostatus  deletado  \
# 0             0.34            2.00               1.00          1.00      0.00
# 1             0.34            4.00               1.00          1.00      0.00
# 2             7.00            2.00               1.00          1.00      0.00
# 3             0.34            1.00               1.00          1.00      0.00
# 4             0.34            2.00               1.00          1.00      0.00
# ..             ...             ...                ...           ...       ...
# 215           9.00            2.00               1.00          1.00      0.00
# 216           9.00            2.00               1.00          1.00      0.00
# 217           9.00            2.00               1.00          1.00      0.00
# 218            NaN             NaN                NaN           NaN       NaN
# 219            NaN             NaN                NaN           NaN       NaN
#
#     nomeproduto unidadeproduto
# 0     Produto A             KG
# 1     Produto A             KG
# 2     Produto C             KG
# 3     Produto A             KG
# 4     Produto A             KG
# ..          ...            ...
# 215  Produto CH             KG
# 216  Produto CH             KG
# 217  Produto CH             KG
# 218  Produto AA             KG
# 219        None             KG
#
# [220 rows x 12 columns]

# %% [markdown]
# ## Consultando uma Views

# %%
SQL_Query = pd.read_sql_query('select * FROM vwvendas_resumida', conn)
view_vendasresumida = pd.DataFrame(SQL_Query)

# %%
view_vendasresumida
# Out:
#            data      cliente     produto
# 0    2010-02-01   Cliente AA   Produto A
# 1    2010-02-01   Cliente BB   Produto A
# 2    2010-02-02   Cliente BC   Produto C
# 3    2010-02-03   Cliente CC   Produto A
# 4    2010-03-05   Cliente DD   Produto A
# ..          ...          ...         ...
# 213  2020-04-01  Cliente GRM  Produto CH
# 214  2023-02-01  Cliente GRM  Produto CH
# 215  2023-03-01  Cliente GRM  Produto CH
# 216  2023-04-01  Cliente GRM  Produto CH
# 217  2023-04-07  Cliente GRM  Produto CH
#
# [218 rows x 3 columns]

# %% [markdown]
# ## Análise Exploratória de Dados do PostgreSQL

# %%
# Visualizando as 5 primeiras linhas do Dataframe
fato_vendas.head()
# Out:
#    codigovenda   datavenda  codigocliente  codigoproduto  quantidade  \
# 0            1  2010-02-01              1           1.00        4000
# 1            2  2010-02-01              1            NaN        4000
# 2            3  2010-02-01              5           1.00        4200
# 3            4  2010-02-02              3           2.00         250
# 4            5  2010-02-03              4           1.00        4500
#
#    valorunitario  codigovendedor  codigocanalvendas  codigostatus  deletado
# 0           0.34               2                  1             1         0
# 1           0.34               2                  1             1         0
# 2           0.34               4                  1             1         0
# 3           7.00               2                  1             1         0
# 4           0.34               1                  1             1         0

# %%
# Visualizando as informações de colunas do Dataframe
fato_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   codigovenda        219 non-null    int64
#  1   datavenda          219 non-null    object
#  2   codigocliente      219 non-null    int64
#  3   codigoproduto      218 non-null    float64
#  4   quantidade         219 non-null    int64
#  5   valorunitario      219 non-null    float64
#  6   codigovendedor     219 non-null    int64
#  7   codigocanalvendas  219 non-null    int64
#  8   codigostatus       219 non-null    int64
#  9   deletado           219 non-null    int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 17.2+ KB

# %% [markdown]
# **Informações estatísticas das colunas Dataframe**
# - contagens
# - média
# - valores máximo e mínimo
# - desvio padrão
# - quartis...

# %%
fato_vendas.describe()
# lembra que vimos lá no SQL?
# Out:
#        codigovenda  codigocliente  codigoproduto  quantidade  valorunitario  \
# count       219.00         219.00         218.00      219.00         219.00
# mean        123.26           9.46           2.38    17257.81           2.73
# std          75.09           5.45           1.74    15244.07           3.45
# min           1.00           1.00           1.00      250.00           0.25
# 25%          58.50           5.00           1.00     9500.00           0.34
# 50%         116.00           9.00           2.00    14200.00           0.34
# 75%         189.50          14.00           4.00    20030.00           7.00
# max         251.00          18.00           6.00    91750.00           9.00
#
#        codigovendedor  codigocanalvendas  codigostatus  deletado
# count          219.00             219.00        219.00    219.00
# mean             4.49               1.19          1.10      0.01
# std              2.93               0.39          0.42      0.12
# min              1.00               1.00          1.00      0.00
# 25%              2.00               1.00          1.00      0.00
# 50%              4.00               1.00          1.00      0.00
# 75%              7.00               1.00          1.00      0.00
# max             10.00               2.00          3.00      1.00

# %% [markdown]
# **Consultando dados nulos ou Missing Values no Dataframe**
#
# Neste caso não tem, isso em um arquivo do dia a dia é raro!

# %%
fato_vendas.isnull().sum()
# Out:
# codigovenda          0
# datavenda            0
# codigocliente        0
# codigoproduto        1
# quantidade           0
# valorunitario        0
# codigovendedor       0
# codigocanalvendas    0
# codigostatus         0
# deletado             0
# dtype: int64

# %% [markdown]
# ### Aprofundando na Análise Exploratória de Dados

# %%
# Importando bibliotecas que usaremos para visualizar as análises
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Define um estilo para nossos plots
plt.style.use('ggplot')

# %% [markdown]
# **Plota a distribuição da variável `Quantidade`**
#
# - Essa é a variável que contem a Quantidade de Vendas.

# %%
sns.displot(fato_vendas['quantidade'],color='green', kde=False)
plt.title('Distribuição da coluna Quantidade')
# Out:
# Text(0.5, 1.0, 'Distribuição da coluna Quantidade')

# %% [markdown]
# **Plota a distribuição da variável `Valor Total`**
#
# - Essa é a variável que contem a Valor Total.

# %%
sns.displot(fato_vendas['quantidade']*fato_vendas['valorunitario'],color='green', kde=False)
plt.title('Distribuição do Valor Total')
# Out:
# Text(0.5, 1.0, 'Distribuição do Valor Total')

# %% [markdown]
# **Visualizando a Correlação entre algumas variáveis**
#
# A Correlação de Pearson mede a dependência linear entre duas variáveis ​​X e Y.
#
# O coeficiente resultante é um valor entre -1 e 1 inclusive, onde:
#
# - 1 : Correlação linear positiva perfeita.
# - 0 : Sem correlação linear, as duas variáveis ​​provavelmente não afetam uma à outra.
# - -1 : Correlação linear negativa perfeita.
# Correlação de Pearson é o método padrão da função “corr”.
#
# Mostra:
# - O quanto alguma variável numérica tem correlação com outra variável ?
# - Correlação pode ser positiva ou negativa

# %%
fato_vendas
# Out:
#      codigovenda   datavenda  codigocliente  codigoproduto  quantidade  \
# 0              1  2010-02-01              1           1.00        4000
# 1              2  2010-02-01              1            NaN        4000
# 2              3  2010-02-01              5           1.00        4200
# 3              4  2010-02-02              3           2.00         250
# 4              5  2010-02-03              4           1.00        4500
# ..           ...         ...            ...            ...         ...
# 214          247  2020-04-01             18           5.00       20030
# 215          248  2023-02-01             18           5.00       20030
# 216          249  2023-03-01             18           5.00       20030
# 217          250  2023-04-01             18           5.00       30030
# 218          251  2023-04-07             18           5.00       10030
#
#      valorunitario  codigovendedor  codigocanalvendas  codigostatus  deletado
# 0             0.34               2                  1             1         0
# 1             0.34               2                  1             1         0
# 2             0.34               4                  1             1         0
# 3             7.00               2                  1             1         0
# 4             0.34               1                  1             1         0
# ..             ...             ...                ...           ...       ...
# 214           9.00               2                  1             1         0
# 215           9.00               2                  1             1         0
# 216           9.00               2                  1             1         0
# 217           9.00               2                  1             1         0
# 218           9.00               2                  1             1         0
#
# [219 rows x 10 columns]

# %%
# Uma amostra dos dados
fato_vendas[['codigocliente','codigoproduto','quantidade','valorunitario']].head()
# Out:
#    codigocliente  codigoproduto  quantidade  valorunitario
# 0              1           1.00        4000           0.34
# 1              1            NaN        4000           0.34
# 2              5           1.00        4200           0.34
# 3              3           2.00         250           7.00
# 4              4           1.00        4500           0.34

# %%
# Correlação entre as variáveis
fato_vendas[['codigocliente','codigoproduto','quantidade','valorunitario']].corr()
# Out:
#                codigocliente  codigoproduto  quantidade  valorunitario
# codigocliente           1.00           0.74        0.14           0.32
# codigoproduto           0.74           1.00        0.36           0.38
# quantidade              0.14           0.36        1.00          -0.06
# valorunitario           0.32           0.38       -0.06           1.00

# %% [markdown]
# Plot o `mapa de calor` para visualizar as `correlações`

# %%
correlacoes = fato_vendas[['codigocliente','codigoproduto','quantidade','valorunitario']].corr()

sns.heatmap(correlacoes, annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Quanto teve de vendas por produto?

# %%
fato_vendas['codigoproduto'].value_counts().to_frame()
# Out:
#       codigoproduto
# 1.00            106
# 2.00             42
# 5.00             26
# 6.00             17
# 4.00             16
# 3.00             11

# %% [markdown]
# Quantos clientes compraram distintamente?

# %%
Clientes = fato_vendas['codigocliente'].unique()

# %%
Clientes
# Out:
# array([ 1,  5,  3,  4,  6,  7,  8,  2, 10,  9, 11, 13, 14, 18, 16, 17],
#       dtype=int64)

# %% [markdown]
# Quantas vendas acima de 70.000 Unidades?

# %%
fato_vendas[fato_vendas['quantidade'] > 70000]
# Out:
#      codigovenda   datavenda  codigocliente  codigoproduto  quantidade  \
# 173          206  2021-08-01             17           6.00       71750
# 174          207  2021-08-07             17           6.00       91750
# 185          218  2022-08-29             14           6.00       71750
# 186          219  2022-09-15             14           6.00       91750
# 189          222  2022-08-21              6           6.00       71750
# 190          223  2022-08-23              6           6.00       91750
#
#      valorunitario  codigovendedor  codigocanalvendas  codigostatus  deletado
# 173           0.25               5                  2             1         0
# 174           0.25               5                  2             3         0
# 185           0.25               5                  2             1         0
# 186           0.25               5                  2             3         0
# 189           0.25               5                  2             1         0
# 190           0.25               5                  2             3         0

# %% [markdown]
# **Dispersão**

# %%
# Quanto maior o valor unitário, menor a quantidade vendida

sns.scatterplot(x='quantidade', y='valorunitario', data=fato_vendas)
# Out:
# <AxesSubplot:xlabel='quantidade', ylabel='valorunitario'>

# %%
# Vendo o comportamento da quantidade de vendas por Codigo de Produto
sns.catplot(x='codigoproduto', y='quantidade', data=fato_vendas)

# %%
# Boxplot - Visualizando através de um boxplot
sns.boxplot(x='codigoproduto', y='quantidade', data=fato_vendas)
# Out:
# <AxesSubplot:xlabel='codigoproduto', ylabel='quantidade'>

# %%
dim_produto
# Out:
#    codigoproduto nomeproduto tipoproduto unidadeproduto  saldoproduto  \
# 0              1   Produto A           A             KG         20000
# 1              2   Produto C           A             KG          5000
# 2              3   Produto E           B             KG          2000
# 3              5  Produto CH           A             KG          2000
# 4              4  Produto SL           A             KG         30000
# 5              6  Produto TN           C             KG          1000
# 6              8  Produto AA           A             KG         20000
# 7              9        None           A             KG         20000
#
#      statusproduto
# 0            Ativo
# 1            Ativo
# 2            Ativo
# 3            Ativo
# 4            Ativo
# 5  MVP - validação
# 6            Ativo
# 7          Inativo

# %%
dim_cliente
# Out:
#     CodigoCliente  NomeCliente  Idade  Classificacao Sexo          Cidade  \
# 0               1   Cliente AA     30              3    M   Florianópolis
# 1               5   Cliente BB     20              2    F  Belo Horizonte
# 2               3   Cliente BC     25              4    M        Baturité
# 3               4   Cliente CC     19              2    F       Fortaleza
# 4               6   Cliente DD     19              2    F         Goiânia
# 5               7   Cliente DE     39              5    F     João Pessoa
# 6               8   Cliente EE     26              4    M           Natal
# 7               2   Cliente EF     31              3    M  Belo Horizonte
# 8              10  Cliente ABC     50              1    M       São Paulo
# 9               9  Cliente BCA     25              4    F  Rio de Janeiro
# 10             11  Cliente CCC     18              2    F        Salvador
# 11             13  Cliente MAC     37              5    F          Maceió
# 12             14  Cliente MGS     50              1    F    Campo Grande
# 13             18  Cliente GRM     55              1    M         Gramado
# 14             16  Cliente PIR     32              3    M        Piripiri
# 15             17  Cliente MTG     38              5    F          Palmas
#
#                  Estado    Pais
# 0        Santa Catarina  Brasil
# 1          Minas Gerais  Brasil
# 2                 Ceará  Brasil
# 3                 Ceará  Brasil
# 4                 Goiás  Brasil
# 5               Paraíba  Brasil
# 6   Rio Grande do Norte  Brasil
# 7          Minas Gerais  Brasil
# 8             São Paulo  Brasil
# 9        Rio de Janeiro  Brasil
# 10                Bahia  Brasil
# 11              Alagoas  Brasil
# 12   Mato Grosso do Sul  Brasil
# 13    Rio Grande do Sul  Brasil
# 14                Piauí  Brasil
# 15            Tocantins  Brasil

# %%
# Relação entre Idade e Quantidade comprada
SQL_Query = pd.read_sql_query('select v.*, c.NomeCliente, c.Idade, c.Classificacao, c.Sexo, c.Cidade, c.Estado, Pais from fato_vendas v join dim_cliente c on c.codigocliente = v.CodigoCliente;', conn)
IdadeQuantidade = pd.DataFrame(SQL_Query)

# %%
IdadeQuantidade
# Out:
#      codigovenda   datavenda  codigocliente  codigoproduto  quantidade  \
# 0              1  2010-02-01              1           1.00        4000
# 1              2  2010-02-01              1            NaN        4000
# 2              3  2010-02-01              5           1.00        4200
# 3              4  2010-02-02              3           2.00         250
# 4              5  2010-02-03              4           1.00        4500
# ..           ...         ...            ...            ...         ...
# 214          247  2020-04-01             18           5.00       20030
# 215          248  2023-02-01             18           5.00       20030
# 216          249  2023-03-01             18           5.00       20030
# 217          250  2023-04-01             18           5.00       30030
# 218          251  2023-04-07             18           5.00       10030
#
#      valorunitario  codigovendedor  codigocanalvendas  codigostatus  deletado  \
# 0             0.34               2                  1             1         0
# 1             0.34               2                  1             1         0
# 2             0.34               4                  1             1         0
# 3             7.00               2                  1             1         0
# 4             0.34               1                  1             1         0
# ..             ...             ...                ...           ...       ...
# 214           9.00               2                  1             1         0
# 215           9.00               2                  1             1         0
# 216           9.00               2                  1             1         0
# 217           9.00               2                  1             1         0
# 218           9.00               2                  1             1         0
#
#      nomecliente  idade  classificacao sexo          cidade  \
# 0     Cliente AA     30              3    M   Florianópolis
# 1     Cliente AA     30              3    M   Florianópolis
# 2     Cliente BB     20              2    F  Belo Horizonte
# 3     Cliente BC     25              4    M        Baturité
# 4     Cliente CC     19              2    F       Fortaleza
# ..           ...    ...            ...  ...             ...
# 214  Cliente GRM     55              1    M         Gramado
# 215  Cliente GRM     55              1    M         Gramado
# 216  Cliente GRM     55              1    M         Gramado
# 217  Cliente GRM     55              1    M         Gramado
# 218  Cliente GRM     55              1    M         Gramado
#
#                 estado    pais
# 0       Santa Catarina  Brasil
# 1       Santa Catarina  Brasil
# 2         Minas Gerais  Brasil
# 3                Ceará  Brasil
# 4                Ceará  Brasil
# ..                 ...     ...
# 214  Rio Grande do Sul  Brasil
# 215  Rio Grande do Sul  Brasil
# 216  Rio Grande do Sul  Brasil
# 217  Rio Grande do Sul  Brasil
# 218  Rio Grande do Sul  Brasil
#
# [219 rows x 17 columns]

# %%
# Visualizando a relação entre Idade e Quantidade comprada
plt.figure(1 , figsize = (15 , 6))
for Sexo in ['M' , 'F']:
    plt.scatter(x = 'idade' , y = 'quantidade' , data = IdadeQuantidade[IdadeQuantidade['sexo'] == Sexo], s = 200 , alpha = 0.5 , label = Sexo)
plt.xlabel('Idade'), plt.ylabel('Quantidade') 
plt.title('Idade vs Quantidade')
plt.legend()
plt.show()

# %% [markdown]
# **Distribuição de Idade, Renda Anual e Pontuação de Gastos segmentado por Sexo**

# %%
plt.figure(1 , figsize = (15 , 7))
n = 0 
for cols in ['idade' , 'quantidade' , 'classificacao']:
    n += 1 
    plt.subplot(1 , 3 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    sns.violinplot(x = cols , y = 'sexo' , data = IdadeQuantidade , palette = 'vlag')
    sns.swarmplot(x = cols , y = 'sexo' , data = IdadeQuantidade)
    plt.ylabel('sexo' if n == 1 else '')
    plt.title('Idade, Quantidade e Classificação de Gastos por Sexo' if n == 2 else '')
plt.show()

# %% [markdown]
# ## Visualização de Dados
#
# - Power BI

# %% [markdown]
# ## Modelo Machine Learning - Clusterização
#
# *Machine Learning* é um subgrupo da IA que utiliza técnicas estatísticas para dar aos computadores a habilidade de aprender com dados sem serem explicitamente programados.

# %% [markdown]
# **Algoritmo KMeans**
#
# *   **n_clusters**: número de clusters que queremos gerar com os nossos dados
# *   **init**: se refere ao modo como o algoritmo será inicializado.
# > *k-means++*: É o método padrão, e os centróides serão gerados utilizando um método inteligente que favorece a convergência.
# >>
# > *random*: Se refere ao modo de inicialização de forma aleatória, ou seja, os centróides iniciais serão gerados de forma totalmente aleatória sem um critério para seleção.
# >>
# > *ndarray*: array de valores indicando qual seriam os centróides que o algoritmo deveria utilizar  para a inicialização
#
# * **max_iter**: Quantidade máxima de vezes que o algoritmo irá executar, por padrão o valor é 300 iterações.
# * **n_jobs**: Quantos CPU´s iremos utilizar para executar o K-means.
# * **algorithm**: Versão do algoritmo K-Means a ser utilizada. A versão clássica é executada através do valor full.
#
# **Atributos Importantes**
# > **inertia**: Soma das distâncias quadráticas intra cluster.
# >>
# > **labels_**: Rótulos dos Clusters atribuídos.
# >>
# > **cluster_centers_**: Valores dos Centroides.

# %% [markdown]
# Selecionando o número de clusters através do método Elbow (Soma das distâncias quadráticas intra clusters).

# %%
from sklearn.cluster import KMeans

# %%
X2 = IdadeQuantidade[['quantidade' , 'classificacao']].iloc[: , :].values
inertia = []
for n in range(1 , 11):
    algorithm = (KMeans(n_clusters = n))
    algorithm.fit(X2)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 11) , inertia , 'o')
plt.plot(np.arange(1 , 11) , inertia , '-' , alpha = 0.5)
plt.xlabel('Número de Clusters') , plt.ylabel('Soma das Distâncias Q intra Clusters')
plt.show()

# %% [markdown]
# Inicializando e Computando o KMeans com o valor de 4 clusters

# %%
algorithm = (KMeans(n_clusters = 4))
algorithm.fit(X2)
# Out:
# KMeans(n_clusters=4)

# %%
# Visualizando os dados agrupados
IdadeQuantidade["clusters"] = algorithm.labels_

# %%
IdadeQuantidade
# Out:
#      codigovenda   datavenda  codigocliente  codigoproduto  quantidade  \
# 0              1  2010-02-01              1           1.00        4000
# 1              2  2010-02-01              1            NaN        4000
# 2              3  2010-02-01              5           1.00        4200
# 3              4  2010-02-02              3           2.00         250
# 4              5  2010-02-03              4           1.00        4500
# ..           ...         ...            ...            ...         ...
# 214          247  2020-04-01             18           5.00       20030
# 215          248  2023-02-01             18           5.00       20030
# 216          249  2023-03-01             18           5.00       20030
# 217          250  2023-04-01             18           5.00       30030
# 218          251  2023-04-07             18           5.00       10030
#
#      valorunitario  codigovendedor  codigocanalvendas  codigostatus  deletado  \
# 0             0.34               2                  1             1         0
# 1             0.34               2                  1             1         0
# 2             0.34               4                  1             1         0
# 3             7.00               2                  1             1         0
# 4             0.34               1                  1             1         0
# ..             ...             ...                ...           ...       ...
# 214           9.00               2                  1             1         0
# 215           9.00               2                  1             1         0
# 216           9.00               2                  1             1         0
# 217           9.00               2                  1             1         0
# 218           9.00               2                  1             1         0
#
#      nomecliente  idade  classificacao sexo          cidade  \
# 0     Cliente AA     30              3    M   Florianópolis
# 1     Cliente AA     30              3    M   Florianópolis
# 2     Cliente BB     20              2    F  Belo Horizonte
# 3     Cliente BC     25              4    M        Baturité
# 4     Cliente CC     19              2    F       Fortaleza
# ..           ...    ...            ...  ...             ...
# 214  Cliente GRM     55              1    M         Gramado
# 215  Cliente GRM     55              1    M         Gramado
# 216  Cliente GRM     55              1    M         Gramado
# 217  Cliente GRM     55              1    M         Gramado
# 218  Cliente GRM     55              1    M         Gramado
#
#                 estado    pais  clusters
# 0       Santa Catarina  Brasil         0
# 1       Santa Catarina  Brasil         0
# 2         Minas Gerais  Brasil         0
# 3                Ceará  Brasil         0
# 4                Ceará  Brasil         0
# ..                 ...     ...       ...
# 214  Rio Grande do Sul  Brasil         2
# 215  Rio Grande do Sul  Brasil         2
# 216  Rio Grande do Sul  Brasil         2
# 217  Rio Grande do Sul  Brasil         2
# 218  Rio Grande do Sul  Brasil         0
#
# [219 rows x 18 columns]

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# determining the name of the file
file_name = 'base_clusterizada.xlsx'
  
# saving the excel
IdadeQuantidade.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# Analisando grupos
df_group = IdadeQuantidade.drop(['codigovenda','datavenda','codigocliente', 'codigoproduto', 'valorunitario', 'codigovendedor', 'codigocanalvendas', 'codigostatus', 'deletado', 'idade'],axis=1).groupby("clusters")

# %%
df_group.describe()
# Out:
#          quantidade                                                        \
#               count     mean      std      min      25%      50%      75%
# clusters
# 0            105.00  7734.00  3664.79   250.00  4500.00  9000.00 10500.00
# 1              6.00 81750.00 10954.45 71750.00 71750.00 81750.00 91750.00
# 2             89.00 18911.69  4252.19 13500.00 15250.00 19250.00 22000.00
# 3             19.00 41776.32  7174.85 30750.00 34500.00 42000.00 44500.00
#
#                   classificacao
#               max         count mean  std  min  25%  50%  75%  max
# clusters
# 0        13250.00        105.00 2.68 1.32 1.00 2.00 3.00 4.00 5.00
# 1        91750.00          6.00 2.67 1.86 1.00 1.25 2.00 4.25 5.00
# 2        30030.00         89.00 2.56 1.36 1.00 1.00 2.00 4.00 5.00
# 3        52000.00         19.00 4.05 1.31 2.00 3.00 5.00 5.00 5.00
