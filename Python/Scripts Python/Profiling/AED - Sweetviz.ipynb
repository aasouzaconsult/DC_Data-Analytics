# %% [markdown]
# # Análise Exploratória de dados utilizando o Sweetviz

# %%
# !pip install sweetviz==2.1.4
# Out:
# Collecting sweetviz==2.1.4
#   Downloading sweetviz-2.1.4-py3-none-any.whl (15.1 MB)
#      ---------------------------------------- 15.1/15.1 MB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from sweetviz==2.1.4) (1.10.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from sweetviz==2.1.4) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from sweetviz==2.1.4) (1.23.5)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from sweetviz==2.1.4) (3.7.0)
# Collecting importlib-resources>=1.2.0
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from sweetviz==2.1.4) (4.64.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from sweetviz==2.1.4) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz==2.1.4) (2.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz==2.1.4) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz==2.1.4) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz==2.1.4) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz==2.1.4) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz==2.1.4) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz==2.1.4) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz==2.1.4) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz==2.1.4) (22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz==2.1.4) (2022.7)
# Requirement already satisfied: colorama in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz==2.1.4) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\alex.souza\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz==2.1.4) (1.16.0)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-5.12.0 sweetviz-2.1.4

# %%
import pandas as pd
import sweetviz as sv

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Data-Centric-AI-Community/awesome-data-centric-ai/master/medium/data-profiling-tools/data/hcc.csv')

# %%
report = sv.analyze(df)
report.show_html('report.html')

# %%
# Additional Features
# Let's tweak the "Outcome" feature to enable the exploration of categories ("Male" and "Female") and compare the insights

df.Outcome = pd.Categorical(df.Outcome)
df['Survival'] = df.Outcome.cat.codes

# %%
# Create a Comparison Report
comparison_report = sv.compare_intra(df, df["Gender"] == 'Male', ["Male", "Female"], 'Survival')
comparison_report.show_notebook()

# %%
df.head()
# Out:
#    Gender  Age Alcohol Hallmark          PS Encephalopathy  Hemoglobin HBeAg  \
# 0    Male   67     Yes     AYes      Active           None        13.7    No
# 1  Female   62      No     BYes      Active           None         NaN    No
# 2    Male   78     Yes     CYes  Ambulatory           None         8.9    No
# 3    Male   77     Yes     DYes      Active           None        13.4    No
# 4    Male   76     Yes     EYes      Active           None        14.3    No
#
#      MCV  Total_Bil   O2  Dir_Bil  Ferritin Outcome  Survival
# 0  106.6        2.1  999      0.5       NaN   Alive         0
# 1  103.4        NaN  999      NaN       NaN   Alive         0
# 2   79.8        0.4  999      0.1      16.0   Alive         0
# 3   97.1        0.4  999      0.2       NaN    Dead         1
# 4   95.1        0.7  999      NaN      22.0   Alive         0

# %% [markdown]
# ## Conectando a um banco de dados (PostgreSQL)

# %%
import pyodbc

# Usaremos o PostgreSQL Unicode, se fosse SQL Server, usariamos o ODBC Driver 17 for SQL Server
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'MySQL ODBC 8.0 ANSI Driver',
#  'MySQL ODBC 8.0 Unicode Driver',
#  'SQL Server Native Client 11.0',
#  'ODBC Driver 17 for SQL Server',
#  'SQL Server Native Client RDA 11.0',
#  'ODBC Driver 13 for SQL Server',
#  'Simba Spark ODBC Driver',
#  'Simba Athena ODBC Driver',
#  'SQLite3 ODBC Driver',
#  'SQLite ODBC Driver',
#  'SQLite ODBC (UTF-8) Driver',
#  'PostgreSQL ANSI(x64)',
#  'PostgreSQL Unicode(x64)',
#  'PostgreSQL ANSI',
#  'PostgreSQL Unicode',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)']

# %%
# Suppress all warnings
import warnings
warnings.filterwarnings("ignore")

# Importing the libraries
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
conn = pyodbc.connect(DRIVER = '{PostgreSQL Unicode}',
                      SERVER = 'localhost',
                      DATABASE = 'Financeiro',
                      UID = 'postgres',
                      PWD = 'suasenha')

cursor = conn.cursor()

# %%
SQL_Query = pd.read_sql_query('SELECT * FROM execucao_financeira_despesa', conn)
financeiro = pd.DataFrame(SQL_Query)

# %%
financeiro
# Out:
#            id num_ano    cod_ne codigo_orgao  \
# 0  2020412441    2020  00000001       010001
# 1  2020412442    2020  00000001       010101
# 2  2020412443    2020  00000001       020001
# 3  2020412444    2020  00000001       020001
# 4  2020412445    2020  00000001       020001
# 5  2020412446    2020  00000001       020001
# 6  2020412447    2020  00000001       020001
# 7  2020412448    2020  00000001       020001
# 8  2020412449    2020  00000001       020001
# 9  2020412450    2020  00000001       020001
#
#                                            dsc_orgao cod_credor  \
# 0                             ASSEMBLEIA LEGISLATIVA   00147162
# 1  FUNDO DE PREVIDENCIA PARLAMENTAR DA ASSEMB LEG...   00193294
# 2                       TRIBUNAL DE CONTAS DO ESTADO   00004977
# 3                       TRIBUNAL DE CONTAS DO ESTADO   00004977
# 4                       TRIBUNAL DE CONTAS DO ESTADO   00004977
# 5                       TRIBUNAL DE CONTAS DO ESTADO   00004977
# 6                       TRIBUNAL DE CONTAS DO ESTADO   00004977
# 7                       TRIBUNAL DE CONTAS DO ESTADO   00004977
# 8                       TRIBUNAL DE CONTAS DO ESTADO   00004977
# 9                       TRIBUNAL DE CONTAS DO ESTADO   00004977
#
#                                      dsc_nome_credor cod_fonte  \
# 0                     FABIANA CALIXTO GOMES DINIZ ME        00
# 1  FUNDO DE PREVIDENCIA PARLAMENTAR DA ASSEMB LEG...        70
# 2           EC TRIBUNAL DE CONTAS DO EST DO CEARA           00
# 3           EC TRIBUNAL DE CONTAS DO EST DO CEARA           00
# 4           EC TRIBUNAL DE CONTAS DO EST DO CEARA           00
# 5           EC TRIBUNAL DE CONTAS DO EST DO CEARA           00
# 6           EC TRIBUNAL DE CONTAS DO EST DO CEARA           00
# 7           EC TRIBUNAL DE CONTAS DO EST DO CEARA           00
# 8           EC TRIBUNAL DE CONTAS DO EST DO CEARA           00
# 9           EC TRIBUNAL DE CONTAS DO EST DO CEARA           00
#
#                           dsc_fonte cod_funcao          dsc_funcao cod_item  \
# 0               RECURSOS ORDINÁRIOS         01         LEGISLATIVA    00088
# 1  RECURSOS DIRETAMENTE ARRECADADOS         09  PREVIDÊNCIA SOCIAL    00024
# 2               RECURSOS ORDINÁRIOS         01         LEGISLATIVA    00001
# 3               RECURSOS ORDINÁRIOS         01         LEGISLATIVA    00001
# 4               RECURSOS ORDINÁRIOS         01         LEGISLATIVA    00001
# 5               RECURSOS ORDINÁRIOS         01         LEGISLATIVA    00001
# 6               RECURSOS ORDINÁRIOS         01         LEGISLATIVA    00001
# 7               RECURSOS ORDINÁRIOS         01         LEGISLATIVA    00001
# 8               RECURSOS ORDINÁRIOS         01         LEGISLATIVA    00001
# 9               RECURSOS ORDINÁRIOS         01         LEGISLATIVA    00001
#
#                                   dsc_item cod_item_elemento  \
# 0  DIVULGAÇÃO DAS ATIVIDADES PARLAMENTARES                39
# 1   PROVENTOS DE APOSENTADORIA PARLAMENTAR                92
# 2               VENCIMENTOS - ESTATUTÁRIOS                11
# 3               VENCIMENTOS - ESTATUTÁRIOS                11
# 4               VENCIMENTOS - ESTATUTÁRIOS                11
# 5               VENCIMENTOS - ESTATUTÁRIOS                11
# 6               VENCIMENTOS - ESTATUTÁRIOS                11
# 7               VENCIMENTOS - ESTATUTÁRIOS                11
# 8               VENCIMENTOS - ESTATUTÁRIOS                11
# 9               VENCIMENTOS - ESTATUTÁRIOS                11
#
#                           dsc_item_elemento cod_item_categoria  \
# 0  OUTROS SERVIÇOS DE TERCEIROS - PESSOA JU                  3
# 1         DESPESAS DE EXERCÍCIOS ANTERIORES                  3
# 2   VENCIMENTOS E VANTAGENS FIXAS - PESSOAL                  3
# 3   VENCIMENTOS E VANTAGENS FIXAS - PESSOAL                  3
# 4   VENCIMENTOS E VANTAGENS FIXAS - PESSOAL                  3
# 5   VENCIMENTOS E VANTAGENS FIXAS - PESSOAL                  3
# 6   VENCIMENTOS E VANTAGENS FIXAS - PESSOAL                  3
# 7   VENCIMENTOS E VANTAGENS FIXAS - PESSOAL                  3
# 8   VENCIMENTOS E VANTAGENS FIXAS - PESSOAL                  3
# 9   VENCIMENTOS E VANTAGENS FIXAS - PESSOAL                  3
#
#   dsc_item_categoria cod_item_grupo dsc_item_grupo dsc_modalidade_licitacao  \
# 0   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
# 1   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
# 2   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
# 3   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
# 4   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
# 5   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
# 6   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
# 7   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
# 8   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
# 9   DESPESA CORRENTE           None           None       APLICAÇÕES DIRETAS
#
#   cod_item_modalidade dsc_item_modalidade cod_programa  \
# 0                  90  APLICAÇÕES DIRETAS          258
# 1                  90  APLICAÇÕES DIRETAS          211
# 2                  90  APLICAÇÕES DIRETAS          211
# 3                  90  APLICAÇÕES DIRETAS          211
# 4                  90  APLICAÇÕES DIRETAS          211
# 5                  90  APLICAÇÕES DIRETAS          211
# 6                  90  APLICAÇÕES DIRETAS          211
# 7                  90  APLICAÇÕES DIRETAS          211
# 8                  90  APLICAÇÕES DIRETAS          211
# 9                  90  APLICAÇÕES DIRETAS          211
#
#                               dsc_programa cod_subfuncao       dsc_subfuncao  \
# 0  DESENVOLVIMENTO DO PROCESSO LEGISLATIVO           031    AÇÃO LEGISLATIVA
# 1           GESTÃO ADMINISTRATIVA DO CEARÁ           271  PREVIDÊNCIA BÁSICA
# 2           GESTÃO ADMINISTRATIVA DO CEARÁ           032    CONTROLE EXTERNO
# 3           GESTÃO ADMINISTRATIVA DO CEARÁ           032    CONTROLE EXTERNO
# 4           GESTÃO ADMINISTRATIVA DO CEARÁ           032    CONTROLE EXTERNO
# 5           GESTÃO ADMINISTRATIVA DO CEARÁ           032    CONTROLE EXTERNO
# 6           GESTÃO ADMINISTRATIVA DO CEARÁ           032    CONTROLE EXTERNO
# 7           GESTÃO ADMINISTRATIVA DO CEARÁ           032    CONTROLE EXTERNO
# 8           GESTÃO ADMINISTRATIVA DO CEARÁ           032    CONTROLE EXTERNO
# 9           GESTÃO ADMINISTRATIVA DO CEARÁ           032    CONTROLE EXTERNO
#
#   num_sic    cod_np  vlr_empenho vlr_liquidado  valor_pago  vlr_resto_pagar  \
# 0    None  00000192      8000.00          None     8000.00             0.00
# 1    None  00000003    285708.59          None   285708.59             0.00
# 2    None  00000013   8876387.45          None  4854314.87             0.00
# 3    None  00000014   8876387.45          None  2031559.36             0.00
# 4    None  00000015   8876387.45          None    75897.35             0.00
# 5    None  00000043   8876387.45          None       23.54             0.00
# 6    None  00000044   8876387.45          None      250.00             0.00
# 7    None  00000045   8876387.45          None    24891.31             0.00
# 8    None  00000046   8876387.45          None     4182.81             0.00
# 9    None  00000047   8876387.45          None     1012.89             0.00
#
#   dth_empenho dth_pagamento dth_liquidacao dth_processamento num_ano_np
# 0  2020-01-28    2020-02-05           None        2022-10-27       2020
# 1  2020-01-29    2020-01-31           None        2022-10-27       2020
# 2  2020-01-28    2020-01-30           None        2022-10-27       2020
# 3  2020-01-28    2020-01-30           None        2022-10-27       2020
# 4  2020-01-28    2020-01-30           None        2022-10-27       2020
# 5  2020-01-28    2020-02-07           None        2022-10-27       2020
# 6  2020-01-28    2020-02-07           None        2022-10-27       2020
# 7  2020-01-28    2020-02-07           None        2022-10-27       2020
# 8  2020-01-28    2020-02-07           None        2022-10-27       2020
# 9  2020-01-28    2020-02-07           None        2022-10-27       2020

# %%
report = sv.analyze(financeiro)
report.show_html('financeiro.html')

# %% [markdown]
# ## References
# - https://towardsdatascience.com/awesome-data-science-tools-to-master-in-2023-data-profiling-edition-29d29310f779
